# %% [markdown]
# # CAR PRICE PREDICTOR + DATA ANALYSER

# %% [markdown]
# **Dataset :** https://www.kaggle.com/datasets/austinreese/craigslist-carstrucks-data

# %% [markdown]
# **Business Problem :**
# Used car prices are highly variable and opaque to buyers. The goal is to build a regression model that predicts the fair market price of a used car based on its features , helping buyers avoid overpaying and sellers price competitively.

# %% [markdown]
# **Approaches :**
#
# 1. Importing Libraries
# 2. Importing CSV file
# 3. Data Preprocessing -
#    - Basic Data insights
#    - Finding Duplicates
#    - Outliers
# 4. EDA
#    - Outliers Handling
#    - Data Visualization
# 5. Feature Engineering
#    - Reducing Cardinality
#    - Creating New Features
# 6. Train Test Split
# 7. Model Pipeline
#    - Model Preprocessing
#    - Model Selection
#    - Linear Regression
#    - Creating Pipeline
#    - Evaluation
# 8. Saving Model in Pickle File
# 9. Conclusion

# %% [markdown]
# # 1. Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import (OneHotEncoder,OrdinalEncoder)
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import f_regression,SelectKBest
from sklearn.metrics import (mean_squared_error, mean_absolute_error, r2_score)
import pickle

# %% [markdown]
# # 2. Importing CSV file

# %%
car_price=pd.read_csv("vehicles.csv")

# %% [markdown]
# # 3. Data Preprocessing

# %% [markdown]
# ## 3.1 Basic Data Insights

# %%
car_price.shape
# Out:
# (426880, 26)

# %%
car_price.head()
# Out:
#            id                                                url  \
# 0  7222695916  https://prescott.craigslist.org/cto/d/prescott...
# 1  7218891961  https://fayar.craigslist.org/ctd/d/bentonville...
# 2  7221797935  https://keys.craigslist.org/cto/d/summerland-k...
# 3  7222270760  https://worcester.craigslist.org/cto/d/west-br...
# 4  7210384030  https://greensboro.craigslist.org/cto/d/trinit...
#
#                    region                         region_url  price  year  \
# 0                prescott    https://prescott.craigslist.org   6000   NaN
# 1            fayetteville       https://fayar.craigslist.org  11900   NaN
# 2            florida keys        https://keys.craigslist.org  21000   NaN
# 3  worcester / central MA   https://worcester.craigslist.org   1500   NaN
# 4              greensboro  https://greensboro.craigslist.org   4900   NaN
#
#   manufacturer model condition cylinders  ... size  type paint_color  \
# 0          NaN   NaN       NaN       NaN  ...  NaN   NaN         NaN
# 1          NaN   NaN       NaN       NaN  ...  NaN   NaN         NaN
# 2          NaN   NaN       NaN       NaN  ...  NaN   NaN         NaN
# 3          NaN   NaN       NaN       NaN  ...  NaN   NaN         NaN
# 4          NaN   NaN       NaN       NaN  ...  NaN   NaN         NaN
#
#   image_url description county state lat long posting_date
# 0       NaN         NaN    NaN    az NaN  NaN          NaN
# 1       NaN         NaN    NaN    ar NaN  NaN          NaN
# 2       NaN         NaN    NaN    fl NaN  NaN          NaN
# 3       NaN         NaN    NaN    ma NaN  NaN          NaN
# 4       NaN         NaN    NaN    nc NaN  NaN          NaN
#
# [5 rows x 26 columns]

# %%
car_price.columns
# Out:
# Index(['id', 'url', 'region', 'region_url', 'price', 'year', 'manufacturer',
#        'model', 'condition', 'cylinders', 'fuel', 'odometer', 'title_status',
#        'transmission', 'VIN', 'drive', 'size', 'type', 'paint_color',
#        'image_url', 'description', 'county', 'state', 'lat', 'long',
#        'posting_date'],
#       dtype='object')

# %%
car_price.dtypes
# Out:
# id                int64
# url              object
# region           object
# region_url       object
# price             int64
# year            float64
# manufacturer     object
# model            object
# condition        object
# cylinders        object
# fuel             object
# odometer        float64
# title_status     object
# transmission     object
# VIN              object
# drive            object
# size             object
# type             object
# paint_color      object
# image_url        object
# description      object
# county          float64
# state            object
# lat             float64
# long            float64
# posting_date     object
# dtype: object

# %%
car_price.tail()
# Out:
#                 id                                                url  \
# 426875  7301591192  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426876  7301591187  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426877  7301591147  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426878  7301591140  https://wyoming.craigslist.org/ctd/d/atlanta-2...
# 426879  7301591129  https://wyoming.craigslist.org/ctd/d/atlanta-2...
#
#          region                      region_url  price    year manufacturer  \
# 426875  wyoming  https://wyoming.craigslist.org  23590  2019.0       nissan
# 426876  wyoming  https://wyoming.craigslist.org  30590  2020.0        volvo
# 426877  wyoming  https://wyoming.craigslist.org  34990  2020.0     cadillac
# 426878  wyoming  https://wyoming.craigslist.org  28990  2018.0        lexus
# 426879  wyoming  https://wyoming.craigslist.org  30590  2019.0          bmw
#
#                            model condition    cylinders  ... size       type  \
# 426875         maxima s sedan 4d      good  6 cylinders  ...  NaN      sedan
# 426876  s60 t5 momentum sedan 4d      good          NaN  ...  NaN      sedan
# 426877          xt4 sport suv 4d      good          NaN  ...  NaN  hatchback
# 426878           es 350 sedan 4d      good  6 cylinders  ...  NaN      sedan
# 426879  4 series 430i gran coupe      good          NaN  ...  NaN      coupe
#
#        paint_color                                          image_url  \
# 426875         NaN  https://images.craigslist.org/00o0o_iiraFnHg8q...
# 426876         red  https://images.craigslist.org/00x0x_15sbgnxCIS...
# 426877       white  https://images.craigslist.org/00L0L_farM7bxnxR...
# 426878      silver  https://images.craigslist.org/00z0z_bKnIVGLkDT...
# 426879         NaN  https://images.craigslist.org/00Y0Y_lEUocjyRxa...
#
#                                               description county state  \
# 426875  Carvana is the safer way to buy a car During t...    NaN    wy
# 426876  Carvana is the safer way to buy a car During t...    NaN    wy
# 426877  Carvana is the safer way to buy a car During t...    NaN    wy
# 426878  Carvana is the safer way to buy a car During t...    NaN    wy
# 426879  Carvana is the safer way to buy a car During t...    NaN    wy
#
#               lat       long              posting_date
# 426875  33.786500 -84.445400  2021-04-04T03:21:31-0600
# 426876  33.786500 -84.445400  2021-04-04T03:21:29-0600
# 426877  33.779214 -84.411811  2021-04-04T03:21:17-0600
# 426878  33.786500 -84.445400  2021-04-04T03:21:11-0600
# 426879  33.779214 -84.411811  2021-04-04T03:21:07-0600
#
# [5 rows x 26 columns]

# %%
car_price.describe()
# Out:
#                  id         price           year      odometer  county  \
# count  4.268800e+05  4.268800e+05  425675.000000  4.224800e+05     0.0
# mean   7.311487e+09  7.519903e+04    2011.235191  9.804333e+04     NaN
# std    4.473170e+06  1.218228e+07       9.452120  2.138815e+05     NaN
# min    7.207408e+09  0.000000e+00    1900.000000  0.000000e+00     NaN
# 25%    7.308143e+09  5.900000e+03    2008.000000  3.770400e+04     NaN
# 50%    7.312621e+09  1.395000e+04    2013.000000  8.554800e+04     NaN
# 75%    7.315254e+09  2.648575e+04    2017.000000  1.335425e+05     NaN
# max    7.317101e+09  3.736929e+09    2022.000000  1.000000e+07     NaN
#
#                  lat           long
# count  420331.000000  420331.000000
# mean       38.493940     -94.748599
# std         5.841533      18.365462
# min       -84.122245    -159.827728
# 25%        34.601900    -111.939847
# 50%        39.150100     -88.432600
# 75%        42.398900     -80.832039
# max        82.390818     173.885502

# %%
car_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426880 entries, 0 to 426879
# Data columns (total 26 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            426880 non-null  int64
#  1   url           426880 non-null  object
#  2   region        426880 non-null  object
#  3   region_url    426880 non-null  object
#  4   price         426880 non-null  int64
#  5   year          425675 non-null  float64
#  6   manufacturer  409234 non-null  object
#  7   model         421603 non-null  object
#  8   condition     252776 non-null  object
#  9   cylinders     249202 non-null  object
#  10  fuel          423867 non-null  object
#  11  odometer      422480 non-null  float64
#  12  title_status  418638 non-null  object
#  13  transmission  424324 non-null  object
#  14  VIN           265838 non-null  object
#  15  drive         296313 non-null  object
#  16  size          120519 non-null  object
#  17  type          334022 non-null  object
#  18  paint_color   296677 non-null  object
#  19  image_url     426812 non-null  object
#  20  description   426810 non-null  object
#  21  county        0 non-null       float64
#  22  state         426880 non-null  object
#  23  lat           420331 non-null  float64
#  24  long          420331 non-null  float64
#  25  posting_date  426812 non-null  object
# dtypes: float64(5), int64(2), object(19)
# memory usage: 84.7+ MB

# %% [markdown]
# #### Columns like ['url','region_url','lat','long','posting_date','image_url','description','county','description','VIN','id'] does not affects the price of car therefore removing them.

# %%
car_price=car_price.drop(columns=
                         ['url','region_url','lat','long','posting_date','image_url','description','county','description','VIN','id','size'])

# %%
car_price=car_price.drop(columns='region')

# %% [markdown]
# #### columns left after dropping noise columns are :

# %%
car_price.columns
# Out:
# Index(['price', 'year', 'manufacturer', 'model', 'condition', 'cylinders',
#        'fuel', 'odometer', 'title_status', 'transmission', 'drive', 'type',
#        'paint_color', 'state'],
#       dtype='object')

# %% [markdown]
# #### Finding percentage of total Null values for each column

# %%
def null_percentage():
    for col in car_price.columns:
        print(f"{col} null value percentage:")
        print(f"{( car_price[col].isnull().sum() ) / (car_price.shape[0]) *100} % \n")

null_percentage()
# Out:
# price null value percentage:
# 0.0 %
#
# year null value percentage:
# 0.28228073463268366 %
#
# manufacturer null value percentage:
# 4.133714392803598 %
#
# model null value percentage:
# 1.2361787856071964 %
#
# condition null value percentage:
# 40.78523238380809 %
#
# cylinders null value percentage:
# 41.6224700149925 %
#
# fuel null value percentage:
# 0.7058189655172414 %
#
# odometer null value percentage:
# 1.0307346326836582 %
#
# title_status null value percentage:
# 1.9307533733133435 %
#
# transmission null value percentage:
# 0.5987631184407797 %
#
# drive null value percentage:
# 30.586347451274364 %
#
# type null value percentage:
# 21.752717391304348 %
#
# paint_color null value percentage:
# 30.501077586206897 %
#
# state null value percentage:
# 0.0 %

# %% [markdown]
# #### Since the sum of null values of columns ['transmission','fuel','year','model','odometer','title_status'] are less than 5% therefore removing them as this will not affect the result

# %%
car_price=car_price.dropna(subset=['transmission','fuel','year','model','odometer','title_status'])

# %% [markdown]
# #### Finding the Shape of data after removing null values

# %%
car_price.shape
# Out:
# (405594, 14)

# %% [markdown]
# #### Only 4.95% of data is removed

# %% [markdown]
# ## 3.2 Finding Duplicates

# %%
car_price.duplicated().sum()
# Out:
# np.int64(120590)

# %% [markdown]
# #### there are 52,601 duplicate rows in the DataFrame therefore removing them

# %%
car_price=car_price.drop_duplicates()

# %% [markdown]
# # 3.3 Outliers

# %%
def outliers():
    columns_car=['price',	'year',	'odometer']
    for col in columns_car:
        
        print(col)
        print(f"skewness: {car_price[col].skew()}")
outliers()
# Out:
# price
# skewness: 242.32488137387702
# year
# skewness: -3.2403455015242613
# odometer
# skewness: 36.324393961433906

# %% [markdown]
# # 4. EDA(Exploratory Data Analysis)

# %% [markdown]
# ## 4.1 Outlier Handling

# %% [markdown]
# #### The data removed is either:
# - Incomplete records (nulls)
# - Garbage price entries ($500 cars, billion dollar entries)

# %% [markdown]
# #### For Price

# %%
car_price['price'].sort_values(ascending=False).head(20)
# Out:
# 356716    3736928711
# 318592    3736928711
# 91576     3024942282
# 257840    3024942282
# 184704    1410065407
# 153082    1234567890
# 29386     1111111111
# 230753     135008900
# 207080     123456789
# 358555     123456789
# 288356     123456789
# 307488     123456789
# 137807     123456789
# 193736     123456789
# 1838        99999999
# 379133      25003000
# 136516      17000000
# 353641      11111111
# 300308      10004000
# 105843       6995495
# Name: price, dtype: int64

# %%
car_price['price'].sort_values(ascending=False).tail(20)
# Out:
# 407600    0
# 407617    0
# 196425    0
# 365609    0
# 146568    0
# 407634    0
# 407633    0
# 124284    0
# 352702    0
# 407630    0
# 407629    0
# 407627    0
# 390365    0
# 407626    0
# 62064     0
# 222923    0
# 407623    0
# 407622    0
# 222935    0
# 373099    0
# Name: price, dtype: int64

# %%
car_price= car_price[
    (car_price['price'] >=1000 ) & 
    (car_price['price'] <=100000)]

# %% [markdown]
# #### 320,679  →  after price filtering (lost ~21%)

# %%
plt.figure(figsize=(14,4))
plt.subplot(121)
sns.kdeplot(car_price['price'])
plt.title('price VS Density')

plt.subplot(122)
sns.boxplot(x=car_price['price'])
plt.title('Price outliers')
plt.show()

# %% [markdown]
# #### For Year

# %%
car_price['year'].value_counts().sort_values(ascending=False).head(20)
# Out:
# year
# 2018.0    20298
# 2017.0    18854
# 2013.0    17756
# 2015.0    17249
# 2014.0    16835
# 2016.0    16079
# 2012.0    14382
# 2019.0    13536
# 2011.0    12773
# 2008.0    11818
# 2007.0    10439
# 2010.0    10279
# 2020.0    10174
# 2006.0     9181
# 2009.0     8243
# 2005.0     7763
# 2004.0     6619
# 2003.0     5388
# 2002.0     4256
# 2001.0     3380
# Name: count, dtype: int64

# %%
car_price['year'].value_counts().sort_values(ascending=False).tail(20)
# Out:
# year
# 1935.0    18
# 1933.0    18
# 1942.0    11
# 1926.0     9
# 1924.0     7
# 1925.0     5
# 1944.0     3
# 1900.0     2
# 1913.0     2
# 1921.0     2
# 1945.0     2
# 1920.0     2
# 1910.0     2
# 1918.0     1
# 1916.0     1
# 1943.0     1
# 1922.0     1
# 1915.0     1
# 1901.0     1
# 1905.0     1
# Name: count, dtype: int64

# %%
car_price=car_price[
    car_price['year'] >=1990]

# %% [markdown]
# #### 320,679  →  after year filtering (lost ~3.2%)

# %%
plt.figure(figsize=(14,4))
plt.subplot(121)
sns.kdeplot(car_price['year'])
plt.title('Year VS Density')

plt.subplot(122)
sns.boxplot(x=car_price['year'])
plt.title('Year outliers detection')

plt.show()

# %% [markdown]
# #### For odometer

# %%
car_price['odometer'].sort_values(ascending=False).head(100)
# Out:
# 144436    10000000.0
# 340694    10000000.0
# 305172    10000000.0
# 378708     9999999.0
# 328374     9999999.0
#              ...
# 332713     1755817.0
# 101915     1750000.0
# 392708     1720466.0
# 358667     1711374.0
# 176057     1701289.0
# Name: odometer, Length: 100, dtype: float64

# %%
car_price['odometer'].sort_values(ascending=False).tail(10000)
# Out:
# 304494    7000.0
# 79550     7000.0
# 189804    7000.0
# 34513     7000.0
# 29579     7000.0
#            ...
# 56077        0.0
# 373563       0.0
# 56082        0.0
# 222681       0.0
# 231995       0.0
# Name: odometer, Length: 10000, dtype: float64

# %%
car_price=car_price[
    (car_price['odometer']>=0) &
    (car_price['odometer']<=300000)]

# %%
car_price.shape
# Out:
# (247282, 14)

# %% [markdown]
# #### 320,679  →  after odometer filtering (lost ~2000 rows)

# %%
plt.figure(figsize=(14,4))
plt.subplot(121)
sns.kdeplot(car_price['odometer'])
plt.title('Odometer VS Density')

plt.subplot(122)
sns.boxplot(x=car_price['odometer'])
plt.title('Odometer outliers')
plt.show()

# %% [markdown]
# #### Not Removing ALL Remaining Outliers bacause
# - luxury cars genuinely exist
# - low mileage cars genuinely exist
# - high prices can be real
#
# If aggressively remove all statistical outliers it can cause:
# - model loses real-world variability
# - dataset becomes unrealistic

# %% [markdown]
# ## 4.2 Data Visualization

# %%
sns.heatmap(car_price[['price','odometer','year']].corr(),annot=True)
plt.show()

# %%
sns.scatterplot(x='odometer',y='price',hue='year',data=car_price)
plt.show()
# Out:
# C:\Users\hp\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.barplot(x='fuel',y='price',data=car_price)
plt.show()

# %%
plt.figure(figsize=(14,5))
sns.barplot(x='cylinders',y='price',data=car_price)
plt.show()

# %%
sns.barplot(x='title_status',y='price',data=car_price)
plt.show()

# %%
plt.figure(figsize=(14,6))
sns.barplot(x='paint_color',y='price',data=car_price)
plt.show()

# %%
plt.figure(figsize=(14,6))
sns.barplot(x='condition',y='price',data=car_price)
plt.show()

# %%
sns.countplot(x='fuel', data=car_price)
plt.show()

# %% [markdown]
# # 5. Feature Engineering

# %% [markdown]
# #### Finding Unique values of categorical columns

# %%
categorical_cols=[
    'fuel','transmission','title_status','manufacturer','model','condition','cylinders','drive','type','paint_color',
    'state']
for col in categorical_cols:
    print(f"{col}: {car_price[col].value_counts()}\n")
# Out:
# fuel: fuel
# gas         211335
# other        15850
# diesel       15711
# hybrid        3361
# electric      1025
# Name: count, dtype: int64
#
# transmission: transmission
# automatic    199500
# other         34070
# manual        13712
# Name: count, dtype: int64
#
# title_status: title_status
# clean         237061
# rebuilt         5641
# salvage         3038
# lien            1296
# missing          178
# parts only        68
# Name: count, dtype: int64
#
# manufacturer: manufacturer
# ford               40138
# chevrolet          30105
# toyota             20923
# honda              14177
# nissan             11733
# jeep               10913
# gmc                 9287
# ram                 9113
# bmw                 8644
# dodge               7464
# subaru              6506
# mercedes-benz       6497
# hyundai             6240
# volkswagen          5682
# lexus               5127
# kia                 5049
# audi                4799
# cadillac            4102
# chrysler            3822
# acura               3685
# mazda               3353
# buick               3247
# infiniti            3013
# lincoln             2500
# volvo               2136
# mitsubishi          1994
# mini                1563
# pontiac             1317
# jaguar              1229
# rover               1130
# porsche              774
# saturn               735
# mercury              701
# fiat                 493
# alfa-romeo           488
# tesla                454
# harley-davidson       79
# ferrari               15
# aston-martin          15
# land rover            10
# Name: count, dtype: int64
#
# model: model
# f-150                 4351
# silverado 1500        2883
# 1500                  2343
# camry                 2044
# accord                2006
#                       ...
# 2011 Scion tc            1
# TAHOE Z71                1
# 60 t-5                   1
# SUZUKI SX4 TOURING       1
# 96 Suburban              1
# Name: count, Length: 22297, dtype: int64
#
# condition: condition
# good         77393
# excellent    62750
# like new     15250
# fair          4513
# new            787
# salvage        352
# Name: count, dtype: int64
#
# cylinders: cylinders
# 6 cylinders     58383
# 4 cylinders     50764
# 8 cylinders     40381
# 5 cylinders      1266
# 10 cylinders      846
# other             617
# 3 cylinders       418
# 12 cylinders      106
# Name: count, dtype: int64
#
# drive: drive
# 4wd    76463
# fwd    67433
# rwd    33528
# Name: count, dtype: int64
#
# type: type
# sedan          52961
# SUV            46422
# pickup         21985
# truck          19424
# other          11200
# hatchback      10457
# coupe          10307
# wagon           6411
# van             4856
# convertible     4482
# mini-van        3481
# offroad          396
# bus              343
# Name: count, dtype: int64
#
# paint_color: paint_color
# white     47470
# black     38542
# silver    27435
# blue      19258
# red       18095
# grey      16502
# green      4631
# custom     4263
# brown      4096
# yellow     1165
# orange     1031
# purple      436
# Name: count, dtype: int64
#
# state: state
# ca    25175
# fl    15778
# tx    14093
# ny    11372
# oh     9556
# mi     8171
# pa     8060
# or     7663
# co     7567
# wi     7095
# wa     7091
# nc     7047
# il     7042
# tn     6641
# nj     6557
# az     5884
# ma     5682
# id     5473
# mn     5431
# va     5193
# ia     5143
# ga     4376
# ks     4018
# ok     3919
# in     3812
# sc     3633
# ct     3430
# md     3168
# mt     2941
# al     2917
# nm     2884
# ky     2675
# mo     2492
# nv     2451
# dc     2327
# ar     2088
# nh     2084
# me     1885
# ak     1848
# ri     1801
# la     1786
# vt     1751
# hi     1711
# sd      929
# ut      838
# de      788
# ms      755
# wv      736
# ne      720
# wy      493
# nd      312
# Name: count, dtype: int64

# %%
for col in categorical_cols:
    print(f"{col}: {car_price[col].unique()}\n")
# Out:
# fuel: ['gas' 'other' 'diesel' 'hybrid' 'electric']
#
# transmission: ['other' 'automatic' 'manual']
#
# title_status: ['clean' 'rebuilt' 'lien' 'salvage' 'missing' 'parts only']
#
# manufacturer: ['gmc' 'chevrolet' 'toyota' 'ford' 'jeep' 'nissan' 'ram' 'mazda'
#  'cadillac' 'honda' 'dodge' 'lexus' 'jaguar' 'buick' 'chrysler' 'volvo'
#  'audi' 'infiniti' 'lincoln' 'alfa-romeo' 'subaru' nan 'acura' 'hyundai'
#  'mercedes-benz' 'bmw' 'mitsubishi' 'volkswagen' 'porsche' 'kia' 'ferrari'
#  'mini' 'pontiac' 'fiat' 'rover' 'tesla' 'saturn' 'mercury'
#  'harley-davidson' 'aston-martin' 'land rover']
#
# model: ['sierra 1500 crew cab slt' 'silverado 1500' 'silverado 1500 crew' ...
#  'ATI' 'gand wagoneer' '96 Suburban']
#
# condition: ['good' 'excellent' 'fair' 'like new' nan 'new' 'salvage']
#
# cylinders: ['8 cylinders' '6 cylinders' nan '4 cylinders' '5 cylinders' '3 cylinders'
#  '10 cylinders' 'other' '12 cylinders']
#
# drive: [nan 'rwd' '4wd' 'fwd']
#
# type: ['pickup' 'truck' 'other' nan 'coupe' 'SUV' 'hatchback' 'mini-van' 'sedan'
#  'offroad' 'bus' 'convertible' 'wagon' 'van']
#
# paint_color: ['white' 'blue' 'red' 'black' 'silver' 'grey' nan 'brown' 'yellow'
#  'orange' 'green' 'custom' 'purple']
#
# state: ['al' 'ak' 'az' 'ar' 'ca' 'co' 'ct' 'dc' 'de' 'fl' 'ga' 'hi' 'id' 'il'
#  'in' 'ia' 'ks' 'ky' 'la' 'me' 'md' 'ma' 'mi' 'mn' 'ms' 'mo' 'mt' 'nc'
#  'ne' 'nv' 'nj' 'nm' 'ny' 'nh' 'nd' 'oh' 'ok' 'or' 'pa' 'ri' 'sc' 'sd'
#  'tn' 'tx' 'ut' 'vt' 'va' 'wa' 'wv' 'wi' 'wy']

# %% [markdown]
# ## 5.1 Reducing Cardinality

# %% [markdown]
# #### Taking only top 50 models of the cars and listing left models in "other"

# %%
top_models=car_price['model'].value_counts().nlargest(50).index
top_models
# Out:
# Index(['f-150', 'silverado 1500', '1500', 'camry', 'accord', 'civic',
#        'silverado', 'altima', 'escape', 'wrangler', 'tacoma', 'grand cherokee',
#        'explorer', '2500', 'corolla', 'cr-v', 'mustang', 'focus', 'equinox',
#        'fusion', 'rav4', 'odyssey', 'outback', 'tahoe', 'malibu', 'sonata',
#        'impala', 'prius', 'grand caravan', 'jetta', 'forester', 'sierra 1500',
#        'elantra', 'cruze', 'silverado 2500hd', 'tundra', 'sentra', 'edge',
#        'f-250', 'corvette', 'sierra', 'rogue', 'charger', '3500', 'f150',
#        'highlander', 'wrangler unlimited', 'sienna', 'pilot', '4runner'],
#       dtype='object', name='model')

# %%
car_price['model']=car_price['model'].apply(lambda x: x if x in top_models else 'other')
car_price['model']
# Out:
# 27                 other
# 28        silverado 1500
# 29                 other
# 30                 other
# 31                 other
#                ...
# 426875             other
# 426876             other
# 426877             other
# 426878             other
# 426879             other
# Name: model, Length: 247282, dtype: object

# %%
car_price[['no_of_cylinders','Cylinders']]=car_price['cylinders'].str.split(' ',n=1,expand=True)
car_price[['no_of_cylinders','Cylinders']]
# Out:
#        no_of_cylinders  Cylinders
# 27                   8  cylinders
# 28                   8  cylinders
# 29                   8  cylinders
# 30                   8  cylinders
# 31                   6  cylinders
# ...                ...        ...
# 426875               6  cylinders
# 426876             NaN        NaN
# 426877             NaN        NaN
# 426878               6  cylinders
# 426879             NaN        NaN
#
# [247282 rows x 2 columns]

# %% [markdown]
# #### Dropping cylinders and cylinders columns as only number of cylinders are required

# %%
car_price=car_price.drop(columns=['cylinders','Cylinders'])

# %%
car_price.dtypes
# Out:
# price                int64
# year               float64
# manufacturer        object
# model               object
# condition           object
# fuel                object
# odometer           float64
# title_status        object
# transmission        object
# drive               object
# type                object
# paint_color         object
# state               object
# no_of_cylinders     object
# dtype: object

# %% [markdown]
# ##### Number of cylinders are still in categorical value so converting it.

# %%
car_price['no_of_cylinders'] = pd.to_numeric(
    car_price['no_of_cylinders'],
    errors='coerce'
)

# %% [markdown]
# ## 5.2 Creating New Features

# %% [markdown]
# ### Finding Car Age

# %%
curr_year=datetime.now().year
curr_year
# Out:
# 2026

# %%
car_price['car_age']=curr_year - car_price['year']

# %%
car_price=car_price.drop(columns=['year'])

# %%
car_price.head(5)
# Out:
#     price manufacturer           model  condition fuel  odometer title_status  \
# 27  33590          gmc           other       good  gas   57923.0        clean
# 28  22590    chevrolet  silverado 1500       good  gas   71229.0        clean
# 29  39590    chevrolet           other       good  gas   19160.0        clean
# 30  30990       toyota           other       good  gas   41124.0        clean
# 31  15000         ford           other  excellent  gas  128000.0        clean
#
#    transmission drive    type paint_color state  no_of_cylinders  car_age
# 27        other   NaN  pickup       white    al              8.0     12.0
# 28        other   NaN  pickup        blue    al              8.0     16.0
# 29        other   NaN  pickup         red    al              8.0      6.0
# 30        other   NaN  pickup         red    al              8.0      9.0
# 31    automatic   rwd   truck       black    al              6.0     13.0

# %% [markdown]
# # 6. Train Test Split

# %%
X = car_price.drop(columns=['price'])
Y = car_price['price']

# %%
X_train,X_test,Y_train,Y_test=train_test_split( X , Y , test_size=0.2 , random_state=42)

# %% [markdown]
# # 7. Model Pipeline

# %% [markdown]
# ## 7.1 Preprocessing Pipelines

# %% [markdown]
# ### Why This Fix Works
#
# In condition col if we use simple imputer and ordinal encoder seperately then :
# - imputer and encoder run separately
# - encoder still receives NaN values
#
# After this fix:
# - imputation happens FIRST
# - encoder receives cleaned values
#
# inside SAME mini-pipeline.

# %%
null_values_encoding=ColumnTransformer( [ 

    ("imputer_no_of_cylinders",SimpleImputer(strategy='median'),['no_of_cylinders']),

    ("ohe_manufacturer",Pipeline([
        ("impute",SimpleImputer(strategy='most_frequent') ),
        ("encode",OneHotEncoder(sparse_output=False,handle_unknown='ignore') )
    ]),['manufacturer'] ),
     
    ("ohe_model",OneHotEncoder(sparse_output=False,handle_unknown='ignore'),['model']),
    
    ("ohe_fuel",OneHotEncoder(sparse_output=False,handle_unknown='ignore'),['fuel']),
    
    ("ohe_title_status",OneHotEncoder(sparse_output=False,handle_unknown='ignore'),['title_status']),
    
    ("ohe_transmission",OneHotEncoder(sparse_output=False,handle_unknown='ignore'),['transmission']),

    
    ("ohe_drive",Pipeline([
        ("impute",SimpleImputer(strategy='constant',fill_value='other') ),
        ("encode",OneHotEncoder(sparse_output=False,handle_unknown='ignore') )
    ]),['drive']),

    

    ("ohe_type",Pipeline([
        ("impute",SimpleImputer(strategy='constant',fill_value='other') ),
        ("encode",OneHotEncoder(sparse_output=False,handle_unknown='ignore') )
    ]),['type']),


    

    ("ohe_paint_color",Pipeline([
        ("impute",SimpleImputer(strategy='constant',fill_value='other') ),
        ("encode",OneHotEncoder(sparse_output=False,handle_unknown='ignore'))
    ]),['paint_color']),

    
    ("ohe_state",OneHotEncoder(sparse_output=False,handle_unknown='ignore'),['state']),

    
    ("oe_condition",Pipeline( [
        ("imputer",SimpleImputer(strategy='constant',fill_value='other') ),
        ("encoder",OrdinalEncoder(categories=[['salvage','fair','other','good','excellent','like new','new']] ) )
    ]), ['condition'])
 ], remainder='passthrough')

# %% [markdown]
# ## 7.2 Feature_selection

# %%
features=SelectKBest(score_func=f_regression,k='all')

# %% [markdown]
# ## 7.3 Linear Regression is baseline Model
# therefore not applying feature scaling and log transformer

# %%
lr=LinearRegression()

# %% [markdown]
# ## 7.4 Creating Pipeline

# %%
pipe_lr=Pipeline([
    ("null_values_encoding",null_values_encoding),
    ("features",features),
    ("lr",lr)
])

# %%
pipe_lr.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('null_values_encoding',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('imputer_no_of_cylinders',
#                                                   SimpleImputer(strategy='median'),
#                                                   ['no_of_cylinders']),
#                                                  ('ohe_manufacturer',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encode',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['manufacturer...
#                                                                 sparse_output=False),
#                                                   ['state']),
#                                                  ('oe_condition',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='other',
#                                                                                  strategy='constant')),
#                                                                   ('encoder',
#                                                                    OrdinalEncoder(categories=[['salvage',
#                                                                                                'fair',
#                                                                                                'other',
#                                                                                                'good',
#                                                                                                'excellent',
#                                                                                                'like '
#                                                                                                'new',
#                                                                                                'new']]))]),
#                                                   ['condition'])])),
#                 ('features',
#                  SelectKBest(k='all',
#                              score_func=<function f_regression at 0x000002325F7662A0>)),
#                 ('lr', LinearRegression())])

# %%
X_train_lr_transformed=pipe_lr.named_steps['null_values_encoding'].transform(X_train)
X_train_lr_transformed
# Out:
# array([[6.00000e+00, 0.00000e+00, 0.00000e+00, ..., 4.00000e+00,
#         1.64000e+05, 1.90000e+01],
#        [6.00000e+00, 0.00000e+00, 0.00000e+00, ..., 2.00000e+00,
#         1.49111e+05, 1.30000e+01],
#        [6.00000e+00, 0.00000e+00, 0.00000e+00, ..., 3.00000e+00,
#         1.64000e+05, 2.70000e+01],
#        ...,
#        [6.00000e+00, 0.00000e+00, 0.00000e+00, ..., 2.00000e+00,
#         1.40000e+05, 1.50000e+01],
#        [6.00000e+00, 0.00000e+00, 1.00000e+00, ..., 2.00000e+00,
#         2.89300e+04, 6.00000e+00],
#        [6.00000e+00, 0.00000e+00, 0.00000e+00, ..., 5.00000e+00,
#         1.80000e+05, 1.80000e+01]], shape=(197825, 190))

# %%
lr_features_names=pipe_lr.named_steps['null_values_encoding'].get_feature_names_out()
lr_features_names
# Out:
# array(['imputer_no_of_cylinders__no_of_cylinders',
#        'ohe_manufacturer__manufacturer_acura',
#        'ohe_manufacturer__manufacturer_alfa-romeo',
#        'ohe_manufacturer__manufacturer_aston-martin',
#        'ohe_manufacturer__manufacturer_audi',
#        'ohe_manufacturer__manufacturer_bmw',
#        'ohe_manufacturer__manufacturer_buick',
#        'ohe_manufacturer__manufacturer_cadillac',
#        'ohe_manufacturer__manufacturer_chevrolet',
#        'ohe_manufacturer__manufacturer_chrysler',
#        'ohe_manufacturer__manufacturer_dodge',
#        'ohe_manufacturer__manufacturer_ferrari',
#        'ohe_manufacturer__manufacturer_fiat',
#        'ohe_manufacturer__manufacturer_ford',
#        'ohe_manufacturer__manufacturer_gmc',
#        'ohe_manufacturer__manufacturer_harley-davidson',
#        'ohe_manufacturer__manufacturer_honda',
#        'ohe_manufacturer__manufacturer_hyundai',
#        'ohe_manufacturer__manufacturer_infiniti',
#        'ohe_manufacturer__manufacturer_jaguar',
#        'ohe_manufacturer__manufacturer_jeep',
#        'ohe_manufacturer__manufacturer_kia',
#        'ohe_manufacturer__manufacturer_land rover',
#        'ohe_manufacturer__manufacturer_lexus',
#        'ohe_manufacturer__manufacturer_lincoln',
#        'ohe_manufacturer__manufacturer_mazda',
#        'ohe_manufacturer__manufacturer_mercedes-benz',
#        'ohe_manufacturer__manufacturer_mercury',
#        'ohe_manufacturer__manufacturer_mini',
#        'ohe_manufacturer__manufacturer_mitsubishi',
#        'ohe_manufacturer__manufacturer_nissan',
#        'ohe_manufacturer__manufacturer_pontiac',
#        'ohe_manufacturer__manufacturer_porsche',
#        'ohe_manufacturer__manufacturer_ram',
#        'ohe_manufacturer__manufacturer_rover',
#        'ohe_manufacturer__manufacturer_saturn',
#        'ohe_manufacturer__manufacturer_subaru',
#        'ohe_manufacturer__manufacturer_tesla',
#        'ohe_manufacturer__manufacturer_toyota',
#        'ohe_manufacturer__manufacturer_volkswagen',
#        'ohe_manufacturer__manufacturer_volvo', 'ohe_model__model_1500',
#        'ohe_model__model_2500', 'ohe_model__model_3500',
#        'ohe_model__model_4runner', 'ohe_model__model_accord',
#        'ohe_model__model_altima', 'ohe_model__model_camry',
#        'ohe_model__model_charger', 'ohe_model__model_civic',
#        'ohe_model__model_corolla', 'ohe_model__model_corvette',
#        'ohe_model__model_cr-v', 'ohe_model__model_cruze',
#        'ohe_model__model_edge', 'ohe_model__model_elantra',
#        'ohe_model__model_equinox', 'ohe_model__model_escape',
#        'ohe_model__model_explorer', 'ohe_model__model_f-150',
#        'ohe_model__model_f-250', 'ohe_model__model_f150',
#        'ohe_model__model_focus', 'ohe_model__model_forester',
#        'ohe_model__model_fusion', 'ohe_model__model_grand caravan',
#        'ohe_model__model_grand cherokee', 'ohe_model__model_highlander',
#        'ohe_model__model_impala', 'ohe_model__model_jetta',
#        'ohe_model__model_malibu', 'ohe_model__model_mustang',
#        'ohe_model__model_odyssey', 'ohe_model__model_other',
#        'ohe_model__model_outback', 'ohe_model__model_pilot',
#        'ohe_model__model_prius', 'ohe_model__model_rav4',
#        'ohe_model__model_rogue', 'ohe_model__model_sentra',
#        'ohe_model__model_sienna', 'ohe_model__model_sierra',
#        'ohe_model__model_sierra 1500', 'ohe_model__model_silverado',
#        'ohe_model__model_silverado 1500',
#        'ohe_model__model_silverado 2500hd', 'ohe_model__model_sonata',
#        'ohe_model__model_tacoma', 'ohe_model__model_tahoe',
#        'ohe_model__model_tundra', 'ohe_model__model_wrangler',
#        'ohe_model__model_wrangler unlimited', 'ohe_fuel__fuel_diesel',
#        'ohe_fuel__fuel_electric', 'ohe_fuel__fuel_gas',
#        'ohe_fuel__fuel_hybrid', 'ohe_fuel__fuel_other',
#        'ohe_title_status__title_status_clean',
#        'ohe_title_status__title_status_lien',
#        'ohe_title_status__title_status_missing',
#        'ohe_title_status__title_status_parts only',
#        'ohe_title_status__title_status_rebuilt',
#        'ohe_title_status__title_status_salvage',
#        'ohe_transmission__transmission_automatic',
#        'ohe_transmission__transmission_manual',
#        'ohe_transmission__transmission_other', 'ohe_drive__drive_4wd',
#        'ohe_drive__drive_fwd', 'ohe_drive__drive_other',
#        'ohe_drive__drive_rwd', 'ohe_type__type_SUV', 'ohe_type__type_bus',
#        'ohe_type__type_convertible', 'ohe_type__type_coupe',
#        'ohe_type__type_hatchback', 'ohe_type__type_mini-van',
#        'ohe_type__type_offroad', 'ohe_type__type_other',
#        'ohe_type__type_pickup', 'ohe_type__type_sedan',
#        'ohe_type__type_truck', 'ohe_type__type_van',
#        'ohe_type__type_wagon', 'ohe_paint_color__paint_color_black',
#        'ohe_paint_color__paint_color_blue',
#        'ohe_paint_color__paint_color_brown',
#        'ohe_paint_color__paint_color_custom',
#        'ohe_paint_color__paint_color_green',
#        'ohe_paint_color__paint_color_grey',
#        'ohe_paint_color__paint_color_orange',
#        'ohe_paint_color__paint_color_other',
#        'ohe_paint_color__paint_color_purple',
#        'ohe_paint_color__paint_color_red',
#        'ohe_paint_color__paint_color_silver',
#        'ohe_paint_color__paint_color_white',
#        'ohe_paint_color__paint_color_yellow', 'ohe_state__state_ak',
#        'ohe_state__state_al', 'ohe_state__state_ar',
#        'ohe_state__state_az', 'ohe_state__state_ca',
#        'ohe_state__state_co', 'ohe_state__state_ct',
#        'ohe_state__state_dc', 'ohe_state__state_de',
#        'ohe_state__state_fl', 'ohe_state__state_ga',
#        'ohe_state__state_hi', 'ohe_state__state_ia',
#        'ohe_state__state_id', 'ohe_state__state_il',
#        'ohe_state__state_in', 'ohe_state__state_ks',
#        'ohe_state__state_ky', 'ohe_state__state_la',
#        'ohe_state__state_ma', 'ohe_state__state_md',
#        'ohe_state__state_me', 'ohe_state__state_mi',
#        'ohe_state__state_mn', 'ohe_state__state_mo',
#        'ohe_state__state_ms', 'ohe_state__state_mt',
#        'ohe_state__state_nc', 'ohe_state__state_nd',
#        'ohe_state__state_ne', 'ohe_state__state_nh',
#        'ohe_state__state_nj', 'ohe_state__state_nm',
#        'ohe_state__state_nv', 'ohe_state__state_ny',
#        'ohe_state__state_oh', 'ohe_state__state_ok',
#        'ohe_state__state_or', 'ohe_state__state_pa',
#        'ohe_state__state_ri', 'ohe_state__state_sc',
#        'ohe_state__state_sd', 'ohe_state__state_tn',
#        'ohe_state__state_tx', 'ohe_state__state_ut',
#        'ohe_state__state_va', 'ohe_state__state_vt',
#        'ohe_state__state_wa', 'ohe_state__state_wi',
#        'ohe_state__state_wv', 'ohe_state__state_wy',
#        'oe_condition__condition', 'remainder__odometer',
#        'remainder__car_age'], dtype=object)

# %%
lr_features_names.shape
# Out:
# (190,)

# %% [markdown]
# ## 7.5 Evaluation

# %%
X_train_lr_df=pd.DataFrame(X_train_lr_transformed,columns=lr_features_names,index=X_train.index)
X_train_lr_df.head(10)
# Out:
#         imputer_no_of_cylinders__no_of_cylinders  \
# 388956                                       6.0
# 103998                                       6.0
# 160097                                       6.0
# 184890                                       6.0
# 293428                                       6.0
# 97897                                        6.0
# 363259                                       6.0
# 117370                                       8.0
# 352349                                       6.0
# 290592                                       6.0
#
#         ohe_manufacturer__manufacturer_acura  \
# 388956                                   0.0
# 103998                                   0.0
# 160097                                   0.0
# 184890                                   0.0
# 293428                                   0.0
# 97897                                    0.0
# 363259                                   1.0
# 117370                                   0.0
# 352349                                   0.0
# 290592                                   0.0
#
#         ohe_manufacturer__manufacturer_alfa-romeo  \
# 388956                                        0.0
# 103998                                        0.0
# 160097                                        0.0
# 184890                                        0.0
# 293428                                        0.0
# 97897                                         0.0
# 363259                                        0.0
# 117370                                        0.0
# 352349                                        0.0
# 290592                                        0.0
#
#         ohe_manufacturer__manufacturer_aston-martin  \
# 388956                                          0.0
# 103998                                          0.0
# 160097                                          0.0
# 184890                                          0.0
# 293428                                          0.0
# 97897                                           0.0
# 363259                                          0.0
# 117370                                          0.0
# 352349                                          0.0
# 290592                                          0.0
#
#         ohe_manufacturer__manufacturer_audi  \
# 388956                                  0.0
# 103998                                  0.0
# 160097                                  0.0
# 184890                                  0.0
# 293428                                  0.0
# 97897                                   0.0
# 363259                                  0.0
# 117370                                  0.0
# 352349                                  0.0
# 290592                                  0.0
#
#         ohe_manufacturer__manufacturer_bmw  \
# 388956                                 0.0
# 103998                                 0.0
# 160097                                 0.0
# 184890                                 0.0
# 293428                                 0.0
# 97897                                  0.0
# 363259                                 0.0
# 117370                                 0.0
# 352349                                 0.0
# 290592                                 0.0
#
#         ohe_manufacturer__manufacturer_buick  \
# 388956                                   0.0
# 103998                                   0.0
# 160097                                   0.0
# 184890                                   0.0
# 293428                                   0.0
# 97897                                    0.0
# 363259                                   0.0
# 117370                                   0.0
# 352349                                   0.0
# 290592                                   0.0
#
#         ohe_manufacturer__manufacturer_cadillac  \
# 388956                                      0.0
# 103998                                      0.0
# 160097                                      0.0
# 184890                                      0.0
# 293428                                      0.0
# 97897                                       0.0
# 363259                                      0.0
# 117370                                      0.0
# 352349                                      1.0
# 290592                                      0.0
#
#         ohe_manufacturer__manufacturer_chevrolet  \
# 388956                                       0.0
# 103998                                       0.0
# 160097                                       0.0
# 184890                                       0.0
# 293428                                       0.0
# 97897                                        0.0
# 363259                                       0.0
# 117370                                       0.0
# 352349                                       0.0
# 290592                                       0.0
#
#         ohe_manufacturer__manufacturer_chrysler  ...  ohe_state__state_ut  \
# 388956                                      0.0  ...                  0.0
# 103998                                      0.0  ...                  0.0
# 160097                                      0.0  ...                  0.0
# 184890                                      0.0  ...                  0.0
# 293428                                      0.0  ...                  0.0
# 97897                                       0.0  ...                  0.0
# 363259                                      0.0  ...                  0.0
# 117370                                      0.0  ...                  0.0
# 352349                                      0.0  ...                  0.0
# 290592                                      0.0  ...                  0.0
#
#         ohe_state__state_va  ohe_state__state_vt  ohe_state__state_wa  \
# 388956                  0.0                  1.0                  0.0
# 103998                  0.0                  0.0                  0.0
# 160097                  0.0                  0.0                  0.0
# 184890                  0.0                  0.0                  0.0
# 293428                  0.0                  0.0                  0.0
# 97897                   0.0                  0.0                  0.0
# 363259                  0.0                  0.0                  0.0
# 117370                  0.0                  0.0                  0.0
# 352349                  0.0                  0.0                  0.0
# 290592                  0.0                  0.0                  0.0
#
#         ohe_state__state_wi  ohe_state__state_wv  ohe_state__state_wy  \
# 388956                  0.0                  0.0                  0.0
# 103998                  0.0                  0.0                  0.0
# 160097                  0.0                  0.0                  0.0
# 184890                  0.0                  0.0                  0.0
# 293428                  0.0                  0.0                  0.0
# 97897                   0.0                  0.0                  0.0
# 363259                  0.0                  0.0                  0.0
# 117370                  0.0                  0.0                  0.0
# 352349                  0.0                  0.0                  0.0
# 290592                  0.0                  0.0                  0.0
#
#         oe_condition__condition  remainder__odometer  remainder__car_age
# 388956                      4.0             164000.0                19.0
# 103998                      2.0             149111.0                13.0
# 160097                      3.0             164000.0                27.0
# 184890                      3.0              20676.0                 9.0
# 293428                      3.0             197000.0                19.0
# 97897                       4.0             119820.0                12.0
# 363259                      2.0             120058.0                13.0
# 117370                      2.0              91000.0                18.0
# 352349                      3.0              57384.0                13.0
# 290592                      3.0              20596.0                 8.0
#
# [10 rows x 190 columns]

# %%
y_predict_lr= pipe_lr.predict(X_test)

mse = mean_squared_error(Y_test, y_predict_lr)
mae = mean_absolute_error(Y_test, y_predict_lr)
r2 = r2_score(Y_test, y_predict_lr)

print("MSE:", mse)
print("MAE:", mae)
print("R2 Score:", r2)
# Out:
# MSE: 55338060.42198058
# MAE: 5165.912898437824
# R2 Score: 0.713748648948644

# %% [markdown]
# # 8.Saving Model in Pickle File

# %%
with open("car_price_prediction.pkl",'wb')as f:
    pickle.dump(pipe_lr,f)

# %% [markdown]
# # 9. Conclusion

# %% [markdown]
# ## Model Performance (Baseline)
# | Metric | Value |
# |--------|-------|
# | R² Score | 0.7190100886808364 |
# | MAE | 5279.539151510923 |
# | MSE | 56751592.44492194 |
#
# > **Note:** Linear Regression was used as a **baseline model** to establish a performance benchmark.
# > The model violates the normality-of-residuals assumption due to right-skewed price distribution,
# > so reported metrics should be interpreted as a lower bound, not a final result.
#
# ## Key Findings from EDA
# - Higher odometer readings correlate negatively with price (expected depreciation)
# - Newer cars (lower car_age) command significantly higher prices
# - Diesel and electric fuel types show higher average prices than gas
# - `salvage` title status significantly drops car value
# - 8-cylinder cars price considerably higher than 4-cylinder equivalents
#
# ## Limitations
# - Linear Regression cannot capture non-linear relationships between features and price
# - High-cardinality OHE columns (state, model, manufacturer) add noise in a linear model
# - No cross-validation performed; metrics are from a single 80/20 split
#
# ## Next Steps
# - [ ] Train XGBoost / Random Forest and compare against this baseline
# - [ ] Use 5-fold cross-validation for reliable metric reporting
# - [ ] Experiment with target encoding for high-cardinality columns

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.7.2
